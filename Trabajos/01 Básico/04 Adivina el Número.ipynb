# %% [markdown]
# # Juego Adivina el Número
# #### En este notebook el usuario deberá adivinar el número generado por el sistema, dentro de un número de aciertos pre-establecidos.

# %%
# Antes que nada, debemos importar la librería "random" y "os"
import random as rd
import os

# Luego, se definirán las vidas del jugador
lf = 5

# Finalmente, se definirá el número que deberá adivinar el jugador:
n = rd.randrange(0,10)

# %% [markdown]
# Una vez que se han establecido las variables requeridas para el juego, iniciamos con la ejecución del menú principal:

# %%
print ("Bienvenido al juego!")
while lf>0:
    print("LIFEBAR")
    print("❤️"*lf)

    p = int(input("Adivina el número, ingresa un número del 0 al 10"))

    if p == n:
        print("Ganaste! Fin del juego 🎁🎁🎁🎁")
        break
    else:
        lf = lf-1

    if abs(p-n) < 2:
        print("Caliente!")
    else:
        print("Frío!")

    if p > n:
        print("El número que ingresaste es mayor")
    if p < n:
        print("El número que ingresaste es menor")
   
print("Perdiste!")
# Out:
# Bienvenido al juego!
# LIFEBAR
# ❤️❤️❤️❤️❤️
# Frío!
# El número que ingresaste es mayor
# LIFEBAR
# ❤️❤️❤️❤️
# Frío!
# El número que ingresaste es mayor
# LIFEBAR
# ❤️❤️❤️
# Caliente!
# El número que ingresaste es mayor
# LIFEBAR
# ❤️❤️
# Ganaste! Fin del juego 🎁🎁🎁🎁
# Perdiste!

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=be2c304b-5a85-4014-8c82-67dc5d240a02' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
